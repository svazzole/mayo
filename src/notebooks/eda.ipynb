# %%
import pandas as pd
import numpy as np

# %%
from PIL import Image
import pyvips
import cv2
import matplotlib.pyplot as plt

# %%
image_fn = "/home/svazzole/Downloads/006388_0.tif"

# %%
image = pyvips.Image.new_from_file(image_fn).resize(0.25).numpy()

# %%
cv2.imwrite("test.png", image)
# Out:
# True

# %%
plt.imshow(image)
